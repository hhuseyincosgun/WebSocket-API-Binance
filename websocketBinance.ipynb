# %%
import json
import websocket
import pandas as pd

# %%
symbol = 'btcusdt'
socket = f'wss://stream.binance.com:9443/ws/{symbol}@kline_1s'

# %%
def on_message(ws, message):
    msg = json.loads(message)
    print(msg)
    
def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED FINE----------")

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")


ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
ws.run_forever()
# Out:
# ---------- OPENED CONNECTION ----------
# {'e': 'kline', 'E': 1721935245005, 's': 'BTCUSDT', 'k': {'t': 1721935244000, 'T': 1721935244999, 's': 'BTCUSDT', 'i': '1s', 'f': 3701864921, 'L': 3701864950, 'o': '64858.51000000', 'c': '64856.00000000', 'h': '64858.51000000', 'l': '64856.00000000', 'v': '0.17102000', 'n': 30, 'x': True, 'q': '11092.06727400', 'V': '0.02792000', 'Q': '1810.84959920', 'B': '0'}}
# {'e': 'kline', 'E': 1721935246007, 's': 'BTCUSDT', 'k': {'t': 1721935245000, 'T': 1721935245999, 's': 'BTCUSDT', 'i': '1s', 'f': 3701864951, 'L': 3701864952, 'o': '64856.00000000', 'c': '64856.00000000', 'h': '64856.00000000', 'l': '64856.00000000', 'v': '0.00073000', 'n': 2, 'x': True, 'q': '47.34488000', 'V': '0.00000000', 'Q': '0.00000000', 'B': '0'}}
# ...

# %%
# Initialize lists to store the data
t, o, h, l, c, v = [], [], [], [], [], []

def on_message(ws, message):
    msg = json.loads(message)
    bar = msg['k']

    if bar['x'] == False:
        t.append(bar['t'])
        o.append(bar['o'])
        h.append(bar['h'])
        l.append(bar['l'])
        c.append(bar['c'])
        v.append(bar['v'])


def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED CONNECTION----------")
    bars = {'time':t, 'open':o, 'high':h, 'low':l, 'close':c, 'volume':v}
    df = pd.DataFrame.from_dict(bars)

    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.set_index(df['time'], inplace=True)
    df.drop(columns='time', inplace=True)

    print(df)

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")


# Replace with your Binance WebSocket URL
symbol = 'btcusdt'
socket = f'wss://stream.binance.com:9443/ws/{symbol}@kline_1s'


ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
import json
import websocket
import pandas as pd

symbol = 'btcusdt'
socket = f'wss://stream.binance.com:9443/ws/{symbol}@kline_1s'


# Initialize lists to store the data
t, o, h, l, c, v = [], [], [], [], [], []

def on_message(ws, message):
    global datas
    message = json.loads(message)
    datas = message['k']

    if datas['x'] == False:
        t.append(datas['t'])  #
        o.append(datas['o'])  #
        h.append(datas['h'])  #
        l.append(datas['l'])  #
        c.append(datas['c'])  #
        v.append(datas['v'])  #


def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED CONNECTION----------")
    bars = {'time':t, 'open':o, 'high':h, 'low':l, 'close':c, 'volume':v}
    df = pd.DataFrame.from_dict(bars)

    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.set_index(df['time'], inplace=True)
    df.drop(columns='time', inplace=True)

    print(df)

def on_open(ws):
    print("---------- OPENED ----------")


# Source is a dict

#{'e': 'kline', 'E': 1721935661006, 's': 'BTCUSDT', 
# 'k': {'t': 1721935660000, 'T': 1721935660999, 's': 'BTCUSDT', 
# 'i': '1s', 'f': 3701875681, 'L': 3701875685, 'o': '64985.66000000', 
# 'c': '64985.66000000', 'h': '64985.67000000', 'l': '64985.66000000', 
# 'v': '0.01807000', 'n': 5, 'x': True, 'q': '1174.29090470', 
# 'V': '0.00285000', 'Q': '185.20915950', 'B': '0'}}

ws = websocket.WebSocketApp(socket, on_message=on_message,
                            on_open=on_open,
                            on_error=on_error,
                            on_close=on_close)

# %% [markdown]
# #### Testing

# %%
symbol = 'btcusdt'
socket = f'wss://stream.binance.com:9443/ws/{symbol}@kline_1s'

# %%
def on_message(ws, message):
    message = json.loads(message)
    datas = message['k']
    # Assuming the data is a dictionary containing 't', 'o', 'h', 'l', 'c', 'v' keys
    t = datas.get('t')
    o = datas.get('o')
    h = datas.get('h')
    l = datas.get('l')
    c = datas.get('c')
    v = datas.get('v')
    
    print(f"Time: {t}, Open: {o}, High: {h}, Low: {l}, Close: {c}, Volume: {v}")
    
def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED FINE----------")

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")


ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
import websocket
import json
import pandas as pd
from datetime import datetime

# Initialize an empty DataFrame
columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(columns=columns)

def on_message(ws, message):
    global df
    message = json.loads(message)
    datas = message['k']
    # Assuming the data is a dictionary containing 't'

    price = datas['c']
    event_time = pd.to_datetime(datas['E'], unit='ms')
    df = pd.DataFrame(price, columns=[datas['s']],
                      index=[event_time])
    

def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED FINE----------")

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")


ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
# Initialize an empty DataFrame
# columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']

columns = ['Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(columns=columns)
df.index.name = 'Event Time'

def on_message(ws, message):
    global df
    msg = json.loads(message)
    out = msg['k']

    # Event Time
    event_time = pd.to_datetime(msg['E'], unit='ms')
    # Open price
    open = float(out['o'])
    # High price
    high = float(out['h'])
    #Low price
    low = float(out['l'])
    # Close price
    close = float(out['c'])
    # Volume 
    volume = float(out['v'])


    
    # Append the new data to the DataFrame
    new_row = pd.DataFrame({'Open': open, 'High': high, 'Low': low, 
                            'Close': close, 'Volume': volume}, index=[event_time])
    
    new_row.index.name = 'Event Time'
    df = pd.concat([df, new_row])
    

    print(df)

def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED FINE----------")

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")

ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
# Initialize an empty DataFrame
# columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume']

columns = ['Event Time', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(columns=columns)
df.set_index('Event Time', inplace=True)

def on_message(ws, message):
    global df
    msg = json.loads(message)
    out = msg['k']

    # Event Time
    event_time = pd.to_datetime(msg['E'], unit='ms')
    # Open price
    open = float(out['o'])
    # High price
    high = float(out['h'])
    #Low price
    low = float(out['l'])
    # Close price
    close = float(out['c'])
    # Volume 
    volume = float(out['v'])


   # Append the new data to the DataFrame
    new_row = pd.DataFrame({'Open': [open], 'High': [high], 
                            'Low': [low], 'Close': [close], 'Volume': [volume]}, index=[event_time])
    
    df = pd.concat([df, new_row])

    print(df)

def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("---------- CLOSED FINE----------")

def on_open(ws):
    print("---------- OPENED CONNECTION ----------")

ws = websocket.WebSocketApp(socket,
                            on_open=on_open,
                            on_message=on_message,
                            on_error=on_error,
                            on_close=on_close)

# %%
ws.run_forever()
# Out:
# ---------- OPENED CONNECTION ----------
#                             Open     High      Low    Close   Volume
# Event Time
# 2024-07-25 21:09:44.006  65264.0  65264.0  65264.0  65264.0  0.00454
# C:\Users\90506\AppData\Local\Temp\ipykernel_20432\4101635446.py:33: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   df = pd.concat([df, new_row])
# C:\Users\90506\AppData\Local\Temp\ipykernel_20432\4101635446.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row])
# ...
